# %% [markdown]
# # Text Pre-processing
# 1. Text Normalization Techniques (Tokenization, Stopwords/Punctuation removal, Stemming, Lemmatization)
# * 1.1 Tokenization - Word tokenization, Regular expression tokenizer, Blank line tokeinzer, Sentence tokenization (punkt)
# * 1.2 Stopwords and Punctuation - removing stopwords and punctuations
# * 1.3 Stemming
# * 1.4 Lemmatization
# 2. Word Grouping (Bigrams, Trigrams, NGrams)
# 3. Feature Extraction (POS Tagging, NER Tagging)

# %% [markdown]
# ## 1.1 Tokenization

# %%
# !pip install nltk

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> l
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
# ...

# %%
import nltk
# from nltk.tokenize import word_tokenize
# from nltk.probability import FreqDist
# import re

# %%
gold = """Gold is a chemical element with symbol Au (from Latin: aurum) and atomic number 79, making it one of the higher atomic number elements that occur naturally. In its purest form, it is a bright, slightly reddish yellow, dense, soft, malleable, and ductile metal. Chemically, gold is a transition metal and a group 11 element. It is one of the least reactive chemical elements and is solid under standard conditions. Gold often occurs in free elemental (native) form, as nuggets or grains, in rocks, in veins, and in alluvial deposits. It occurs in a solid solution series with the native element silver (as electrum) and also naturally alloyed with copper and palladium. Less commonly, it occurs in minerals as gold compounds, often with tellurium (gold tellurides).

Gold is resistant to most acids, though it does dissolve in aqua regia, a mixture of nitric acid and hydrochloric acid, which forms a soluble tetrachloroaurate anion. Gold is insoluble in nitric acid, which dissolves silver and base metals, a property that has long been used to refine gold and to confirm the presence of gold in metallic objects, giving rise to the term acid test. Gold also dissolves in alkaline solutions of cyanide, which are used in mining and electroplating. Gold dissolves in mercury, forming amalgam alloys, but this is not a chemical reaction.

A relatively rare element,[5][6] gold is a precious metal that has been used for coinage, jewelry, and other arts throughout recorded history. In the past, a gold standard was often implemented as a monetary policy, but gold coins ceased to be minted as a circulating currency in the 1930s, and the world gold standard was abandoned for a fiat currency system after 1971.

A total of 186,700 tonnes of gold exists above ground, as of 2015.[7] The world consumption of new gold produced is about 50% in jewelry, 40% in investments, and 10% in industry.[8] Gold's high malleability, ductility, resistance to corrosion and most other chemical reactions, and conductivity of electricity have led to its continued use in corrosion resistant electrical connectors in all types of computerized devices (its chief industrial use). Gold is also used in infrared shielding, colored-glass production, gold leafing, and tooth restoration. Certain gold salts are still used as anti-inflammatories in medicine. As of 2016, the world's largest gold producer by far was China with 450 tonnes per year"""

# %%
type(gold), len(gold)
# Out:
# (str, 2421)

# %% [markdown]
# ### Word tokenization

# %% [markdown]
# Spacy: https://spacy.io/

# %%
from nltk.tokenize import word_tokenize
gold_word_tokenize = word_tokenize(gold)

# %%
print(gold_word_tokenize) # tokens
# Out:
# ['Gold', 'is', 'a', 'chemical', 'element', 'with', 'symbol', 'Au', '(', 'from', 'Latin', ':', 'aurum', ')', 'and', 'atomic', 'number', '79', ',', 'making', 'it', 'one', 'of', 'the', 'higher', 'atomic', 'number', 'elements', 'that', 'occur', 'naturally', '.', 'In', 'its', 'purest', 'form', ',', 'it', 'is', 'a', 'bright', ',', 'slightly', 'reddish', 'yellow', ',', 'dense', ',', 'soft', ',', 'malleable', ',', 'and', 'ductile', 'metal', '.', 'Chemically', ',', 'gold', 'is', 'a', 'transition', 'metal', 'and', 'a', 'group', '11', 'element', '.', 'It', 'is', 'one', 'of', 'the', 'least', 'reactive', 'chemical', 'elements', 'and', 'is', 'solid', 'under', 'standard', 'conditions', '.', 'Gold', 'often', 'occurs', 'in', 'free', 'elemental', '(', 'native', ')', 'form', ',', 'as', 'nuggets', 'or', 'grains', ',', 'in', 'rocks', ',', 'in', 'veins', ',', 'and', 'in', 'alluvial', 'deposits', '.', 'It', 'occurs', 'in', 'a', 'solid', 'solution', 'series', 'with', 'the', 'native', 'element', 'silver', '(
# ...

# %%
gold_word_tokenize[1]
# Out:
# 'is'

# %%
len(gold_word_tokenize)
# Out:
# 479

# %%
from nltk.probability import FreqDist
# create an instance of the FreqDist class with an empty dictionary
fdist = FreqDist()

# %%
for word in gold_word_tokenize:
    #fdist[word.lower()]+=1
    fdist[word]+=1

# %%
fdist
# Out:
# FreqDist({',': 39, 'in': 20, '.': 18, 'and': 17, 'a': 14, 'gold': 14, 'of': 12, 'is': 11, 'the': 9, 'Gold': 8, ...})

# %%
len(fdist)
# Out:
# 230

# %%
fdist['gold']
# Out:
# 14

# %%
fdist["The"]
# Out:
# 1

# %%
fdist["the"]
# Out:
# 9

# %%
for word in gold_word_tokenize:
    fdist[word.lower()]+=1 #Convert to lower case
    #fdist[word]+=1

# %%
fdist["the"]
# Out:
# 19

# %%
len(fdist)
# Out:
# 236

# %%
fdist_top10=fdist.most_common(10) # 10 most occurring tokens
fdist_top10
# Out:
# [(',', 78),
#  ('in', 42),
#  ('.', 36),
#  ('gold', 36),
#  ('and', 34),
#  ('a', 30),
#  ('of', 24),
#  ('is', 22),
#  ('the', 19),
#  ('as', 15)]

# %% [markdown]
# CheatSheet RegEx -->
#
# https://cheatography.com/davechild/cheat-sheets/regular-expressions/pdf/

# %% [markdown]
# ### Regular expression tokenization and Blank line tokenization

# %%
from nltk.tokenize import regexp_tokenize, blankline_tokenize

# %%
mytokens = regexp_tokenize(gold,pattern='\d+')
print(mytokens)
# Out:
# ['79', '11', '5', '6', '1930', '1971', '186', '700', '2015', '7', '50', '40', '10', '8', '2016', '450']

# %%
mytokens = regexp_tokenize(gold,pattern='\d')
print(mytokens)
# Out:
# ['7', '9', '1', '1', '5', '6', '1', '9', '3', '0', '1', '9', '7', '1', '1', '8', '6', '7', '0', '0', '2', '0', '1', '5', '7', '5', '0', '4', '0', '1', '0', '8', '2', '0', '1', '6', '4', '5', '0']

# %%
gold_bl_tokenize=blankline_tokenize(gold)
len(gold_bl_tokenize)
# Out:
# 4

# %%
gold_bl_tokenize[0]
# Out:
# 'Gold is a chemical element with symbol Au (from Latin: aurum) and atomic number 79, making it one of the higher atomic number elements that occur naturally. In its purest form, it is a bright, slightly reddish yellow, dense, soft, malleable, and ductile metal. Chemically, gold is a transition metal and a group 11 element. It is one of the least reactive chemical elements and is solid under standard conditions. Gold often occurs in free elemental (native) form, as nuggets or grains, in rocks, in veins, and in alluvial deposits. It occurs in a solid solution series with the native element silver (as electrum) and also naturally alloyed with copper and palladium. Less commonly, it occurs in minerals as gold compounds, often with tellurium (gold tellurides).'

# %%
gold
# Out:
# "Gold is a chemical element with symbol Au (from Latin: aurum) and atomic number 79, making it one of the higher atomic number elements that occur naturally. In its purest form, it is a bright, slightly reddish yellow, dense, soft, malleable, and ductile metal. Chemically, gold is a transition metal and a group 11 element. It is one of the least reactive chemical elements and is solid under standard conditions. Gold often occurs in free elemental (native) form, as nuggets or grains, in rocks, in veins, and in alluvial deposits. It occurs in a solid solution series with the native element silver (as electrum) and also naturally alloyed with copper and palladium. Less commonly, it occurs in minerals as gold compounds, often with tellurium (gold tellurides).\n\nGold is resistant to most acids, though it does dissolve in aqua regia, a mixture of nitric acid and hydrochloric acid, which forms a soluble tetrachloroaurate anion. Gold is insoluble in nitric acid, which dissolves silver and b
# ...

# %%
gold_bl_tokenize[2]
# Out:
# 'A relatively rare element,[5][6] gold is a precious metal that has been used for coinage, jewelry, and other arts throughout recorded history. In the past, a gold standard was often implemented as a monetary policy, but gold coins ceased to be minted as a circulating currency in the 1930s, and the world gold standard was abandoned for a fiat currency system after 1971.'

# %% [markdown]
# ### Sentence tokenization

# %% [markdown]
# **Punkt Sentence Tokenizer** This tokenizer divides a text into a list of sentences, by using an unsupervised algorithm to build a model for abbreviation words, collocations, and words that start sentences. It must be trained on a large collection of plaintext in the target language before it can be used
#
# It is a **sentence boundary** detection algorithm that must be trained to be used. **NLTK already includes a pre-trained version** of the Punkt Sentence Tokenizer
#
# The sent_tokenize() uses the pre-trained punkt english model from nltk_data/tokenizers/punkt/english.pickle. You can also specify other languages.
#
#
# Training can be done on Tokenizer: (Documentation)
#
# https://www.nltk.org/api/nltk.tokenize.html#nltk.tokenize.punkt.PunktTrainer

# %%
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\navan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
gold_sent_tokenize = sent_tokenize(gold)

# %%
gold_sent_tokenize[0]
# Out:
# 'Gold is a chemical element with symbol Au (from Latin: aurum) and atomic number 79, making it one of the higher atomic number elements that occur naturally.'

# %%
gold_sent_tokenize
# Out:
# ['Gold is a chemical element with symbol Au (from Latin: aurum) and atomic number 79, making it one of the higher atomic number elements that occur naturally.',
#  'In its purest form, it is a bright, slightly reddish yellow, dense, soft, malleable, and ductile metal.',
#  'Chemically, gold is a transition metal and a group 11 element.',
#  'It is one of the least reactive chemical elements and is solid under standard conditions.',
#  'Gold often occurs in free elemental (native) form, as nuggets or grains, in rocks, in veins, and in alluvial deposits.',
#  'It occurs in a solid solution series with the native element silver (as electrum) and also naturally alloyed with copper and palladium.',
#  'Less commonly, it occurs in minerals as gold compounds, often with tellurium (gold tellurides).',
#  'Gold is resistant to most acids, though it does dissolve in aqua regia, a mixture of nitric acid and hydrochloric acid, which forms a soluble tetrachloroaurate anion.',
# ...

# %% [markdown]
# ## 1.2 Stopwords and Punctuations

# %% [markdown]
# ### Removing Stopwords

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\navan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords_english = set(stopwords.words('english'))
print(stopwords_english)
# Out:
# {'weren', 'and', 'to', 'above', 'again', 'now', "you've", 'then', 'do', "mightn't", 'been', 'there', 'needn', 'those', 'shan', "weren't", 'their', 'ma', "isn't", 'between', 'the', 'both', 'him', 'more', 'mustn', 'where', "wasn't", 'if', 'into', 'me', 'own', 'shouldn', 'such', 'for', 'each', 'are', 'very', 'few', 'or', 'should', 'we', 're', 't', "won't", 'was', "you'd", 'will', 'this', 'does', 'didn', 'has', 'further', 'same', 'hasn', 'down', 'she', 'most', 'don', 'during', 'these', 'up', 'them', 'his', 'as', "hasn't", 'about', 'is', 'hers', "didn't", 'being', 'than', 'of', 'before', 'a', 'through', 'your', 'on', 'have', "she's", 'an', "aren't", 'my', 'other', 'by', 'did', 'some', 'll', 'yourselves', 'why', 'they', "wouldn't", 'doesn', 'ourselves', 'that', 'its', 'too', 's', 'haven', 'it', 'had', "should've", 'over', 'he', "you're", 'd', 'no', 'any', "needn't", 'who', 'ours', 'am', 'wasn', 'once', 'nor', 'myself', 'her', 'ain', "doesn't", 'o', 'until', 'yourself', 'yours', 'under', 'w
# ...

# %%
len(stopwords_english)
# Out:
# 179

# %%
len(gold_word_tokenize)
# Out:
# 479

# %%
# Convert words to same case (lower)
gold_word_tokenize = [word.lower() for word in gold_word_tokenize]

# %%
gold_word_tokenize
# Out:
# ['gold',
#  'is',
#  'a',
#  'chemical',
#  'element',
#  'with',
#  'symbol',
#  'au',
#  '(',
#  'from',
#  'latin',
#  ':',
#  'aurum',
#  ')',
#  'and',
#  'atomic',
#  'number',
#  '79',
#  ',',
#  'making',
#  'it',
#  'one',
#  'of',
#  'the',
#  'higher',
#  'atomic',
#  'number',
#  'elements',
#  'that',
#  'occur',
#  'naturally',
#  '.',
#  'in',
#  'its',
#  'purest',
#  'form',
#  ',',
#  'it',
#  'is',
#  'a',
#  'bright',
#  ',',
#  'slightly',
#  'reddish',
#  'yellow',
#  ',',
#  'dense',
#  ',',
#  'soft',
#  ',',
#  'malleable',
#  ',',
#  'and',
#  'ductile',
#  'metal',
#  '.',
#  'chemically',
#  ',',
#  'gold',
#  'is',
#  'a',
#  'transition',
#  'metal',
#  'and',
#  'a',
#  'group',
#  '11',
#  'element',
#  '.',
#  'it',
#  'is',
#  'one',
#  'of',
#  'the',
#  'least',
#  'reactive',
#  'chemical',
#  'elements',
#  'and',
#  'is',
#  'solid',
#  'under',
#  'standard',
#  'conditions',
#  '.',
#  'gold',
#  'often',
#  'occurs',
#  'in',
#  'free',
# ...

# %%
 #list after removing stopwords
post_stopwords = [word for word in gold_word_tokenize if word not in stopwords_english]

# %%
len(post_stopwords), len(gold_word_tokenize)
# Out:
# (326, 479)

# %%
print(post_stopwords)
# Out:
# ['gold', 'chemical', 'element', 'symbol', 'au', '(', 'latin', ':', 'aurum', ')', 'atomic', 'number', '79', ',', 'making', 'one', 'higher', 'atomic', 'number', 'elements', 'occur', 'naturally', '.', 'purest', 'form', ',', 'bright', ',', 'slightly', 'reddish', 'yellow', ',', 'dense', ',', 'soft', ',', 'malleable', ',', 'ductile', 'metal', '.', 'chemically', ',', 'gold', 'transition', 'metal', 'group', '11', 'element', '.', 'one', 'least', 'reactive', 'chemical', 'elements', 'solid', 'standard', 'conditions', '.', 'gold', 'often', 'occurs', 'free', 'elemental', '(', 'native', ')', 'form', ',', 'nuggets', 'grains', ',', 'rocks', ',', 'veins', ',', 'alluvial', 'deposits', '.', 'occurs', 'solid', 'solution', 'series', 'native', 'element', 'silver', '(', 'electrum', ')', 'also', 'naturally', 'alloyed', 'copper', 'palladium', '.', 'less', 'commonly', ',', 'occurs', 'minerals', 'gold', 'compounds', ',', 'often', 'tellurium', '(', 'gold', 'tellurides', ')', '.', 'gold', 'resistant', 'acids', '
# ...

# %%
# from nltk.probability import FreqDist
# # create an instance of the FreqDist class with an empty dictionary
fdist = FreqDist()
fdist_poststopwords = FreqDist()
for word in post_stopwords:
    fdist_poststopwords[word]+=1
fdist_poststopwords
# Out:
# FreqDist({',': 39, 'gold': 22, '.': 18, '(': 5, ')': 5, 'used': 5, 'chemical': 4, 'element': 4, 'acid': 4, '[': 4, ...})

# %% [markdown]
# **Note: For sentiment analysis we need to be careful while removing stop words. We may be removing words that signify some sentiment**

# %% [markdown]
# ### Removing Punctuations

# %%
import string
punctuations = string.punctuation

# %%
punctuations
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#list after removing punctuation
post_punctuation = [word for word in gold_word_tokenize if word not in punctuations]

# post_punctuation = list()
# for word in gold_word_tokenize:
#     if word not in puncuations:
#         post_punctuation.append(word)

# %%
len(post_punctuation), len(gold_word_tokenize)
# Out:
# (400, 479)

# %% [markdown]
# ### Removing Punctuations and Stopwords

# %%
post_stopwords_punctuation = [word.lower() for word in gold_word_tokenize 
                              if word not in stopwords_english and word not in punctuations]

len(gold_word_tokenize), len(post_stopwords), len(post_punctuation), len(post_stopwords_punctuation)
# Out:
# (479, 326, 400, 247)

# %%
fdist_new=FreqDist()
for word in post_stopwords_punctuation:
    fdist_new[word]+=1

len(fdist_new)
# Out:
# 182

# %%
fdist_new
# Out:
# FreqDist({'gold': 22, 'used': 5, 'chemical': 4, 'element': 4, 'acid': 4, 'metal': 3, 'standard': 3, 'often': 3, 'occurs': 3, 'also': 3, ...})

# %%
print(fdist_new.most_common(10))
# Out:
# [('gold', 22), ('used', 5), ('chemical', 4), ('element', 4), ('acid', 4), ('metal', 3), ('standard', 3), ('often', 3), ('occurs', 3), ('also', 3)]

# %% [markdown]
# **We can see that using some basic cleaning techniques (tokenization, stop words removal, punctuation removal -- we can get the core common words from the document - which does give an idea of what the document may be talking about !!!**

# %% [markdown]
# ## 1.3 Stemming

# %%
from nltk.stem import PorterStemmer, LancasterStemmer, SnowballStemmer

# %%
pst = PorterStemmer()

# %%
pst.stem("having")
# Out:
# 'have'

# %%
words_to_stem=["give","giving","given","gave", "studying", "study", "studies"]

# %%
for words in words_to_stem:
    print(words+ ":" +pst.stem(words))
# Out:
# give:give
# giving:give
# given:given
# gave:gave
# studying:studi
# study:studi
# studies:studi

# %%
lst=LancasterStemmer()

# %%
for words in words_to_stem:
    print(words+ ":" +lst.stem(words))
# Out:
# give:giv
# giving:giv
# given:giv
# gave:gav
# studying:study
# study:study
# studies:study

# %%
sbst=SnowballStemmer('english')

# %%
sbst.languages
# Out:
# ('arabic',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'hungarian',
#  'italian',
#  'norwegian',
#  'porter',
#  'portuguese',
#  'romanian',
#  'russian',
#  'spanish',
#  'swedish')

# %%
sbst.stem('having')
# Out:
# 'have'

# %%
for words in words_to_stem:
    print(words+ ":" +sbst.stem(words))
# Out:
# give:give
# giving:give
# given:given
# gave:gave
# studying:studi
# study:studi
# studies:studi

# %%
def stemms(word):
    print("Porter:"+pst.stem(word))
    print("Lancaster:"+lst.stem(word))
    print("Snowball:"+sbst.stem(word))
    return

# %%
stemms('taking')
# Out:
# Porter:take
# Lancaster:tak
# Snowball:take

# %%
stemms('data')
# Out:
# Porter:data
# Lancaster:dat
# Snowball:data

# %%
stemms('corpora')
# Out:
# Porter:corpora
# Lancaster:corpor
# Snowball:corpora

# %%
stemms('corpus')
# Out:
# Porter:corpu
# Lancaster:corp
# Snowball:corpus

# %%
stemms('curricula')
# Out:
# Porter:curricula
# Lancaster:curricul
# Snowball:curricula

# %%
stemms('curriculum')
# Out:
# Porter:curriculum
# Lancaster:curricul
# Snowball:curriculum

# %% [markdown]
# ## 1.4 Lemmatization

# %% [markdown]
# * **WordNet** is a lexical database for the English language, which was created by Princeton, and is part of the NLTK corpus. You can use WordNet alongside the NLTK module to find the meanings of words, synonyms, antonyms, and more
# * WordNet is the **lexical database** i.e. dictionary for the English language, specifically designed for natural language processing.
# * **Synset** (synonym set) is a special kind of a simple interface that is present in NLTK to look up words in WordNet
# * Synset instances are the groupings of synonymous words that express the same concept

# %%
nltk.download('wordnet')
# from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\navan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
word_lem=WordNetLemmatizer()

# %%
word_lem.lemmatize('corpora'), word_lem.lemmatize('corpus')
# Out:
# ('corpus', 'corpus')

# %%
word_lem.lemmatize('curricula'), word_lem.lemmatize('curriculum')
# Out:
# ('curriculum', 'curriculum')

# %%
word_lem.lemmatize('better', pos='a') # 'a' for pos parameter denotes adjective
# Out:
# 'good'

# %%
#words_to_stem:

words_to_lem = ['cats','cacti','geese','rocks','python','run']
for words in words_to_lem:
    print(words+ ":" +word_lem.lemmatize(words))
# Out:
# cats:cat
# cacti:cactus
# geese:goose
# rocks:rock
# python:python
# run:run

# %%
for words in words_to_stem:
    print(words+ ":" +word_lem.lemmatize(words))
# Out:
# give:give
# giving:giving
# given:given
# gave:gave
# studying:studying
# study:study
# studies:study

# %%
print(word_lem.lemmatize("better", pos="a"))
print(word_lem.lemmatize("best", pos="a"))
print(word_lem.lemmatize("run",'v'))
print(word_lem.lemmatize("ran",'v'))
# Out:
# good
# best
# run
# run

# %% [markdown]
# *Returns the input word unchanged if it cannot be found in WordNet*

# %% [markdown]
# ## 2.1 Bigrams, Trigrams and Ngrams

# %%
from nltk.util import bigrams, trigrams, ngrams

# %%
string = "The Mona Lisa is a half length portrait painting by the Italian Renaissance artist Leonardo da Vinci"

# %%
mona_lisa_tokens = nltk.word_tokenize(string)

# %%
len(mona_lisa_tokens)
# Out:
# 17

# %%
mona_lisa_bigrams=list(nltk.bigrams(mona_lisa_tokens))

# %%
mona_lisa_bigrams
# Out:
# [('The', 'Mona'),
#  ('Mona', 'Lisa'),
#  ('Lisa', 'is'),
#  ('is', 'a'),
#  ('a', 'half'),
#  ('half', 'length'),
#  ('length', 'portrait'),
#  ('portrait', 'painting'),
#  ('painting', 'by'),
#  ('by', 'the'),
#  ('the', 'Italian'),
#  ('Italian', 'Renaissance'),
#  ('Renaissance', 'artist'),
#  ('artist', 'Leonardo'),
#  ('Leonardo', 'da'),
#  ('da', 'Vinci')]

# %%
mona_lisa_trigrams=list(nltk.trigrams(mona_lisa_tokens))

# %%
mona_lisa_trigrams
# Out:
# [('The', 'Mona', 'Lisa'),
#  ('Mona', 'Lisa', 'is'),
#  ('Lisa', 'is', 'a'),
#  ('is', 'a', 'half'),
#  ('a', 'half', 'length'),
#  ('half', 'length', 'portrait'),
#  ('length', 'portrait', 'painting'),
#  ('portrait', 'painting', 'by'),
#  ('painting', 'by', 'the'),
#  ('by', 'the', 'Italian'),
#  ('the', 'Italian', 'Renaissance'),
#  ('Italian', 'Renaissance', 'artist'),
#  ('Renaissance', 'artist', 'Leonardo'),
#  ('artist', 'Leonardo', 'da'),
#  ('Leonardo', 'da', 'Vinci')]

# %%
mona_lisa_ngrams=list(nltk.ngrams(mona_lisa_tokens, 5))

# %%
mona_lisa_ngrams
# Out:
# [('The', 'Mona', 'Lisa', 'is', 'a'),
#  ('Mona', 'Lisa', 'is', 'a', 'half'),
#  ('Lisa', 'is', 'a', 'half', 'length'),
#  ('is', 'a', 'half', 'length', 'portrait'),
#  ('a', 'half', 'length', 'portrait', 'painting'),
#  ('half', 'length', 'portrait', 'painting', 'by'),
#  ('length', 'portrait', 'painting', 'by', 'the'),
#  ('portrait', 'painting', 'by', 'the', 'Italian'),
#  ('painting', 'by', 'the', 'Italian', 'Renaissance'),
#  ('by', 'the', 'Italian', 'Renaissance', 'artist'),
#  ('the', 'Italian', 'Renaissance', 'artist', 'Leonardo'),
#  ('Italian', 'Renaissance', 'artist', 'Leonardo', 'da'),
#  ('Renaissance', 'artist', 'Leonardo', 'da', 'Vinci')]

# %% [markdown]
# ##### N-grams find their use in Language Modelling, where based on occurrence of co-located tokens or n-grams the next word in a sequence is predicted

# %% [markdown]
# ## 3.1 POS Tagging
# **punkt** is used for tokenising sentences and **averaged_perceptron_tagger** is used for tagging words with their parts of speech (POS)

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\navan\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
sentence = "The dog chased the cat"
sent_tokens = word_tokenize(sentence)
sent_tokens
# Out:
# ['The', 'dog', 'chased', 'the', 'cat']

# %%
nltk.pos_tag(sent_tokens)
# for token in sent_tokens:
#     print(nltk.pos_tag([token]))
# Out:
# [('The', 'DT'), ('dog', 'NN'), ('chased', 'VBD'), ('the', 'DT'), ('cat', 'NN')]

# %%
for token in sent_tokens:
    print(nltk.pos_tag([token]))
# Out:
# [('The', 'DT')]
# [('dog', 'NN')]
# [('chased', 'VBN')]
# [('the', 'DT')]
# [('cat', 'NN')]

# %%
sentence = "John is eating a delicious cake"
sent_tokens = word_tokenize(sentence)
sent_tokens
# Out:
# ['John', 'is', 'eating', 'a', 'delicious', 'cake']

# %%
nltk.pos_tag(sent_tokens)
# for token in sent_tokens:
#     print(nltk.pos_tag([token]))
# Out:
# [('John', 'NNP'),
#  ('is', 'VBZ'),
#  ('eating', 'VBG'),
#  ('a', 'DT'),
#  ('delicious', 'JJ'),
#  ('cake', 'NN')]

# %%
sentence = "John eats an apple"
sent_tokens = word_tokenize(sentence)
nltk.pos_tag(sent_tokens)
# for token in sent_tokens:
#     print(nltk.pos_tag([token]))
# Out:
# [('John', 'NNP'), ('eats', 'VBZ'), ('an', 'DT'), ('apple', 'NN')]

# %%
sentence = 'In the face of despair, you believe there can be hope.'
sent_tokens = word_tokenize(sentence)
print(sent_tokens)
# Out:
# ['In', 'the', 'face', 'of', 'despair', ',', 'you', 'believe', 'there', 'can', 'be', 'hope', '.']

# %%
nltk.pos_tag(sent_tokens)
# Out:
# [('In', 'IN'),
#  ('the', 'DT'),
#  ('face', 'NN'),
#  ('of', 'IN'),
#  ('despair', 'NN'),
#  (',', ','),
#  ('you', 'PRP'),
#  ('believe', 'VBP'),
#  ('there', 'EX'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('hope', 'VBN'),
#  ('.', '.')]

# %% [markdown]
# * IN – Preposition
# * DT – Determiner
# * NN – Noun
# * PRP – Personal pronoun
# * EX – Existential there
# * MD – Modal verb
# * VB – Verb base form
# * VBN – Verb past participle

# %% [markdown]
# ### Some common POS tags and their descriptions
# ![POS_abbreviations.png](attachment:POS_abbreviations.png)

# %% [markdown]
# * **Noun:** a word (other than a pronoun) used to identify any of a class of people, places, or things ( common noun ), or to name a particular one of these ( proper noun
# * **Verb:** a word used to describe an action, state, or occurrence, and forming the main part of the predicate of a sentence, such as hear, become, happen.
# * **Verb Gerund:** A gerund is the form of a verb that ends with the letters “ing”. Such words act like a noun. For example, in the sentence "I love learning," the word "learning" is a gerund
# * **Verb Past participle:** For regular verbs, adding -ed to the base form creates the past participle. For example, the past participle of cook is cooked. Past participles formed from irregular verbs may have endings like -en, -t, -d, and -n
# * **Verb 3rd person singular present:**  the third person singular in the simple present tense always ends in –s: she climbs, he runs, it rains, etc
# * **Pronoun:** a word that can function as a noun phrase used by itself and that refers either to the participants in the discourse (e.g. I, you ) or to someone or something mentioned elsewhere in the discourse (e.g. she, it, this ).
# * **Adjective:** a word naming an attribute of a noun, such as sweet, red, or technical.
# * **Adverb:** a word or phrase that modifies or qualifies an adjective, verb, or other adverb or a word group, expressing a relation of place, time, circumstance, manner, cause, degree, etc. (e.g., gently, quite, then, there ).
# * **Preposition:** a word governing, and usually preceding, a noun or pronoun and expressing a relation to another word or element in the clause, as in ‘the man on the platform’, ‘she arrived after dinner’, ‘what did you do it for
# * **Conjunction:** a word used to connect clauses or sentences or to coordinate words in the same clause (e.g. and, but, if ).
#
# * **Interjection:** an abrupt remark, especially as an aside or interruption e.g. Hurrah! We won the game! ( Emotion of joy) Alas! I failed the exam! ( Emotion of sorrow)
# * **Article:** Articles are words that define a noun as specific or unspecific. Consider the following examples: After the long day, the cup of tea tasted particularly good. By using the article the, we've shown that it was one specific day that was long and one specific cup of tea that tasted good

# %% [markdown]
# ### POS Example

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
hamlet=nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')

# %%
len(hamlet)
# Out:
# 37360

# %%
hamlet
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', ...]

# %%
hamlet_pos = []
for word in hamlet[:2000]:
    word_pos=nltk.pos_tag([word])
    hamlet_pos.append(word_pos)

# %%
hamlet_pos
# Out:
# [[('[', 'NN')],
#  [('The', 'DT')],
#  [('Tragedie', 'NN')],
#  [('of', 'IN')],
#  [('Hamlet', 'NN')],
#  [('by', 'IN')],
#  [('William', 'NNP')],
#  [('Shakespeare', 'NN')],
#  [('1599', 'CD')],
#  [(']', 'NN')],
#  [('Actus', 'NN')],
#  [('Primus', 'NN')],
#  [('.', '.')],
#  [('Scoena', 'NN')],
#  [('Prima', 'NN')],
#  [('.', '.')],
#  [('Enter', 'NN')],
#  [('Barnardo', 'NN')],
#  [('and', 'CC')],
#  [('Francisco', 'NNP')],
#  [('two', 'CD')],
#  [('Centinels', 'NNS')],
#  [('.', '.')],
#  [('Barnardo', 'NN')],
#  [('.', '.')],
#  [('Who', 'WP')],
#  [("'", "''")],
#  [('s', 'NN')],
#  [('there', 'RB')],
#  [('?', '.')],
#  [('Fran', 'NN')],
#  [('.', '.')],
#  [('Nay', 'NN')],
#  [('answer', 'NN')],
#  [('me', 'PRP')],
#  [(':', ':')],
#  [('Stand', 'NN')],
#  [('&', 'CC')],
#  [('vnfold', 'NN')],
#  [('your', 'PRP$')],
#  [('selfe', 'NN')],
#  [('Bar', 'NN')],
#  [('.', '.')],
#  [('Long', 'RB')],
#  [('liue', 'NN')],
#  [('the', 'DT')],
#  [('King', 'VBG')],
# ...

# %%
hamlet_pos[0]
# Out:
# [('[', 'NN')]

# %%
hamlet_pos[0][0]
# Out:
# ('[', 'NN')

# %%
hamlet_pos[0][0][1]
# Out:
# 'NN'

# %%
hamlet_nnp = []
for each_pos in hamlet_pos:
    if each_pos[0][1] =='NNP': #get pos
        hamlet_nnp.append(each_pos[0][0]) # add the word

# %%
hamlet_nnp
# Out:
# ['William',
#  'Francisco',
#  'Francisco',
#  'Westward',
#  'Bell',
#  'God',
#  'Mart',
#  'Sunday',
#  'Doth',
#  'Doth',
#  'God',
#  'Day',
#  'Sea',
#  'Wherein',
#  'Kingdome',
#  'Bedrid']

# %%
same_names = ["William","william"]

# %%
for each_name in same_names:
    print(nltk.pos_tag([each_name]))
# Out:
# [('William', 'NNP')]
# [('william', 'NN')]

# %% [markdown]
# ## 3.2 NER Tagging

# %%
from nltk import ne_chunk
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\navan\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\navan\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
NE_sent = "The US President stays in the White House"
NE_tokens = word_tokenize(NE_sent)
NE_tags = nltk.pos_tag(NE_tokens)

# %%
NE_tags
# Out:
# [('The', 'DT'),
#  ('US', 'NNP'),
#  ('President', 'NNP'),
#  ('stays', 'VBZ'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('White', 'NNP'),
#  ('House', 'NNP')]

# %%
NE_NER = ne_chunk(NE_tags)
print(NE_NER)
# Out:
# (S
#   The/DT
#   (ORGANIZATION US/NNP)
#   President/NNP
#   stays/VBZ
#   in/IN
#   the/DT
#   (FACILITY White/NNP House/NNP))

# %% [markdown]
# *Here the NER tagging for US is not correct... its not an organization, it should have been tagged as a country...
# You may need to use a better tagger, like Stanford NER Tagger*

# %%
NE_sent = "apple CEO Tim Cook introduces 2 new large IPhones, Smartwatch at Cupertina Flint Center Event"
NE_tokens = word_tokenize(NE_sent)
NE_tags = nltk.pos_tag(NE_tokens)

# %%
NE_tags
# Out:
# [('apple', 'NN'),
#  ('CEO', 'NNP'),
#  ('Tim', 'NNP'),
#  ('Cook', 'NNP'),
#  ('introduces', 'VBZ'),
#  ('2', 'CD'),
#  ('new', 'JJ'),
#  ('large', 'JJ'),
#  ('IPhones', 'NNS'),
#  (',', ','),
#  ('Smartwatch', 'NNP'),
#  ('at', 'IN'),
#  ('Cupertina', 'NNP'),
#  ('Flint', 'NNP'),
#  ('Center', 'NNP'),
#  ('Event', 'NNP')]

# %%
NE_NER = ne_chunk(NE_tags)
print(NE_NER)
# Out:
# (S
#   apple/NN
#   (ORGANIZATION CEO/NNP Tim/NNP Cook/NNP)
#   introduces/VBZ
#   2/CD
#   new/JJ
#   large/JJ
#   (ORGANIZATION IPhones/NNS)
#   ,/,
#   (PERSON Smartwatch/NNP)
#   at/IN
#   (FACILITY Cupertina/NNP Flint/NNP Center/NNP)
#   Event/NNP)

# %%
NE_sent = "Narendra Modi is the Prime Minister of India"
NE_tokens = word_tokenize(NE_sent)
NE_tags = nltk.pos_tag(NE_tokens)

# %%
NE_tags
# Out:
# [('Narendra', 'NNP'),
#  ('Modi', 'NNP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('Prime', 'NNP'),
#  ('Minister', 'NNP'),
#  ('of', 'IN'),
#  ('India', 'NNP')]

# %%
NE_NER = ne_chunk(NE_tags)
print(NE_NER)
# Out:
# (S
#   (PERSON Narendra/NNP)
#   (ORGANIZATION Modi/NNP)
#   is/VBZ
#   the/DT
#   Prime/NNP
#   Minister/NNP
#   of/IN
#   (GPE India/NNP))
